# %%
import pandas as pd
df = pd.read_csv('Pregnancy Risk.csv')
df.sample(5)
# Out:
#      Unnamed: 0  Age  Height  Weight    BMI Blood Group ( is Negative?)  \
# 496         496   21   1.447    52.6  25.09                          No
# 541         541   23   1.244    68.0  31.33                          No
# 299         299   18   1.422    40.0  19.77                          No
# 668         668   21   1.524    54.6  23.51                          No
# 325         325   19   1.549    61.7  25.70                          No
#
#     Delivery Type  Systolic Blood Pressure  Diastolic Blood Pressure   Edema  \
# 496   No_delivary                       90                        60  Normal
# 541        Normal                      120                        80  Normal
# 299   No_delivary                      120                        80  Normal
# 668   No_delivary                      110                        80  Normal
# 325   No_delivary                      100                        80  Normal
#
#        Anemia Jaundice Diabetes Risk  Para  Gravida
# ...

# %%
df.shape
# Out:
# (916, 16)

# %%
df1 = df.drop(['Unnamed: 0'],axis=1)
df1.head(5)
# Out:
#    Age  Height  Weight    BMI Blood Group ( is Negative?) Delivery Type  \
# 0   25   1.600    50.7  19.80                          No   No_delivary
# 1   30   1.524    86.3  37.16                          No        Normal
# 2   26   1.549    58.8  24.49                          No        Normal
# 3   26   1.549    86.8  36.16                          No        Normal
# 4   36   1.422    85.8  42.90                          No        Normal
#
#    Systolic Blood Pressure  Diastolic Blood Pressure   Edema  Anemia Jaundice  \
# 0                      110                        90  Normal  Normal       No
# 1                      110                        80  Normal  Normal       No
# 2                      120                        80  Normal  Normal       No
# 3                      120                        80  Normal  Normal       No
# 4                      110                        80  Normal  Normal       No
#
#   Diabetes Risk  Para  Gravida
# 0       No   No     0        1
# ...

# %%
import seaborn as sn
plt.figure(figsize=(12,8))
sn.histplot(df1.Age[df1.Risk == 'No'])
sn.histplot(df.Age[df.Risk == 'Yes'],color='red')
plt.show()
# Out:
# 0      25
# 1      30
# 2      26
# 3      26
# 4      36
#        ..
# 911    18
# 912    29
# 913    29
# 914    40
# 915    19
# Name: Age, Length: 916, dtype: int64
