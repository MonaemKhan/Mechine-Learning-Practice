# %%
import pandas as pd
df = pd.read_csv('n_spam.csv')
df.head()
# Out:
#   Category                                            Message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...

# %%
result = df.index[df['Message'] == "Please call our customer service representative on FREEPHONE 0808 145 4742 between 9am-11pm as you have WON a guaranteed å£1000 cash or å£5000 prize!"]
result
# Out:
# Int64Index([187, 1001, 4010, 4040], dtype='int64')

# %%
final = df.Category[result]
final.values
# Out:
# array(['spam', 'spam', 'spam', 'spam'], dtype=object)

# %%
for i in range(len(final)):
    print(final.values[i])
# Out:
# spam
# spam
# spam
# spam

# %%
result = df['Message']
result.values
# Out:
# array(['Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...',
#        'Ok lar... Joking wif u oni...',
#        "Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's",
#        ..., 'Pity, * was in mood for that. So...any other suggestions?',
#        "The guy did some bitching but I acted like i'd be interested in buying something else next week and he gave it to us for free",
#        'Rofl. Its true to its name'], dtype=object)

# %%
def detect(x):
    corr = "xyz"
    x = corr+" : "+x
    
    return x

# %%
catch = []
for val in result:
    catch.append(detect(val))
catch
# Out:
# ['xyz : Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...',
#  'xyz : Ok lar... Joking wif u oni...',
#  "xyz : Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's",
#  'xyz : U dun say so early hor... U c already then say...',
#  "xyz : Nah I don't think he goes to usf, he lives around here though",
#  "xyz : FreeMsg Hey there darling it's been 3 week's now and no word back! I'd like some fun you up for it still? Tb ok! XxX std chgs to send, å£1.50 to rcv",
#  'xyz : Even my brother is not like to speak with me. They treat me like aids patent.',
#  "xyz : As per your request 'Melle Melle (Oru Minnaminunginte Nurungu Vettam)' has been set as your callertune for all Callers. Press *9 to copy your friends Callertune",
# ...

# %%
df['correction'] = catch

# %%
df.head()
# Out:
#   Category                                            Message  \
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
#
#                                           correction
# 0  xyz : Go until jurong point, crazy.. Available...
# 1                xyz : Ok lar... Joking wif u oni...
# 2  xyz : Free entry in 2 a wkly comp to win FA Cu...
# 3  xyz : U dun say so early hor... U c already th...
# 4  xyz : Nah I don't think he goes to usf, he liv...

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(df.Message,df.Category,test_size=0.25)
len(x_test)
# Out:
# 1393

# %%
x_test[:3]
# Out:
# 4988    So your telling me I coulda been your real Val...
# 5297    My darling sister. How are you doing. When's s...
# 5072    Gud ni8 dear..slp well..take care..swt dreams....
# Name: Message, dtype: object

# %%
y_test[:3]
# Out:
# 4988    ham
# 5297    ham
# 5072    ham
# Name: Category, dtype: object

# %%
score = {
    'Catagory' : y_test,
    'Message' : x_test
}

# %%
test_set = pd.DataFrame(score)
test_set.head()
# Out:
#      Catagory                                            Message
# 4988      ham  So your telling me I coulda been your real Val...
# 5297      ham  My darling sister. How are you doing. When's s...
# 5072      ham  Gud ni8 dear..slp well..take care..swt dreams....
# 853       ham  \AH POOR BABY!HOPE URFEELING BETTERSN LUV! PRO...
# 1722      ham  Thought praps you meant another one. Goodo! I'...

# %%
score = {
    'Catagory' : y_train,
    'Message' : x_train
}
train_set = pd.DataFrame(score)
train_set.head()
# Out:
#      Catagory                                            Message
# 2054      ham      Y so late but i need to go n get da laptop...
# 3043      ham  Let me know how it changes in the next 6hrs. I...
# 928       ham                            Oh all have to come ah?
# 346       ham  Dis is yijue. I jus saw ur mail. In case huimi...
# 251       ham  Wen ur lovable bcums angry wid u, dnt take it ...
